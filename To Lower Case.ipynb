# %% [markdown]
# ---
# # To Lower Case
#
# **Problem Link:**
# https://leetcode.com/problems/to-lower-case/
#
# ---
#
# ## Problem Statement
#
# Given a string `s`, return the string after replacing every uppercase letter with the same lowercase letter.
#
# ## Examples
#
# ### Example 1
# **Input:**
# `s = "Hello"`
#
# **Output:**
# `"hello"`
#
# ---
#
# ### Example 2
# **Input:**
# `s = "here"`
#
# **Output:**
# `"here"`
#
# ---
#
# ### Example 3
# **Input:**
# `s = "LOVELY"`
#
# **Output:**
# `"lovely"`
#
# ---
#
# ## Constraints
#
# - `1 <= s.length <= 100`
# - `s` consists of printable ASCII characters

# %% [markdown]
# # Test Cases
# ---

# %%
def test_to_lower_case(solution):
    test_cases = [
        ("Hello", "hello"),
        ("here", "here"),
        ("LOVELY", "lovely"),
        ("PyThOn123", "python123"),
    ]

    for s, expected in test_cases:
        result = solution.toLowerCase(s)
        assert result == expected, f"Failed for {s}: expected {expected}, got {result}"

    print("All test cases passed!")

# %% [markdown]
# # Approach
# ---

# %% [markdown]
# ## Built-in String Conversion
#
# ### Strategy
# - Use Python's built-in `lower()` method
# - Automatically converts all uppercase characters to lowercase
#
# ### Time Complexity
# - **O(n)** where `n` is the length of the string
#
# ### Space Complexity
# - **O(n)** due to creation of a new string

# %%
class Solution:
    def toLowerCase(self, s: str) -> str:
        return s.lower()

# %%
solution = Solution()
test_to_lower_case(solution)
# Out:
# All test cases passed!
