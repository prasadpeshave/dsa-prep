# %% [markdown]
# # Unique Paths II
#
# ## Problem Link
# https://leetcode.com/problems/unique-paths-ii/
#
# ---
#
# ## Problem Statement
# Given a grid with obstacles (1 = obstacle, 0 = free), find the number of unique paths from top-left to bottom-right.
#
# You can only move **right** or **down**, and cannot step on obstacles.

# %% [markdown]
# ## Approach
#
# ### Dynamic Programming (2D DP)
#
# - Let `dp[i][j]` = number of ways to reach cell `(i, j)`
# - If the cell has an obstacle → `dp[i][j] = 0`
# - Otherwise:
#   dp[i][j] = dp[i-1][j] + dp[i][j-1]
#
# - Initialize first row and column carefully
#
# ### Time Complexity
# - O(m * n)
#
# ### Space Complexity
# - O(m * n)

# %%
from typing import List

class Solution:
    def uniquePathsWithObstacles(self, obstacleGrid: List[List[int]]) -> int:
        m, n = len(obstacleGrid), len(obstacleGrid[0])

        dp = [[0] * n for _ in range(m)]

        if obstacleGrid[0][0] == 1:
            return 0
        dp[0][0] = 1

        for i in range(1, m):
            if obstacleGrid[i][0] == 0:
                dp[i][0] = dp[i-1][0]

        for j in range(1, n):
            if obstacleGrid[0][j] == 0:
                dp[0][j] = dp[0][j-1]

        for i in range(1, m):
            for j in range(1, n):
                if obstacleGrid[i][j] == 0:
                    dp[i][j] = dp[i-1][j] + dp[i][j-1]

        return dp[m-1][n-1]

# %% [markdown]
# ## Test Cases

# %%
def test_unique_paths():
    sol = Solution()

    assert sol.uniquePathsWithObstacles([[0,0,0],[0,1,0],[0,0,0]]) == 2
    assert sol.uniquePathsWithObstacles([[0,1],[0,0]]) == 1
    assert sol.uniquePathsWithObstacles([[1]]) == 0

    print('All tests passed!')

test_unique_paths()
# Out:
# All tests passed!
