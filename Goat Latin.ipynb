# %% [markdown]
# ---
# # Goat Latin
#
# **Problem Link:**
# https://leetcode.com/problems/goat-latin/
#
# ---
#
# ## Problem Statement
#
# Convert a sentence to Goat Latin using the following rules:
#
# 1. If a word begins with a vowel (a, e, i, o, u — case insensitive), append "ma".
# 2. If it begins with a consonant, move the first letter to the end and append "ma".
# 3. Add 'a' repeated by its word index (starting from 1).
#
# Return the transformed sentence.
#
# ## Example
#
# Input: "I speak Goat Latin"
#
# Output:
# "Imaa peaksmaaa oatGmaaaa atinLmaaaaa"

# %% [markdown]
# # Approach
# ---

# %% [markdown]
# ## String Processing
#
# ### Steps
# - Split sentence into words
# - Process each word with its index
# - Apply vowel/consonant rule
# - Append 'a' * index
# - Join back into sentence
#
# ### Time Complexity
# - O(n)
#
# ### Space Complexity
# - O(n)

# %%
class Solution:
    def toGoatLatin(self, sentence: str) -> str:
        vowels = set('aeiouAEIOU')
        words = sentence.split()
        result = []

        for i, word in enumerate(words, start=1):
            if word[0] in vowels:
                goat_word = word + 'ma'
            else:
                goat_word = word[1:] + word[0] + 'ma'

            goat_word += 'a' * i
            result.append(goat_word)

        return ' '.join(result)

# %% [markdown]
# # Test Cases
# ---

# %%
def test_goat_latin():
    sol = Solution()

    assert sol.toGoatLatin("I speak Goat Latin") == \
        "Imaa peaksmaaa oatGmaaaa atinLmaaaaa"

    assert sol.toGoatLatin("The quick brown fox jumped over the lazy dog") == \
        "heTmaa uickqmaaa rownbmaaaa oxfmaaaaa umpedjmaaaaaa overmaaaaaaa hetmaaaaaaaa azylmaaaaaaaaa ogdmaaaaaaaaaa"

    print("All test cases passed!")

test_goat_latin()
# Out:
# All test cases passed!
