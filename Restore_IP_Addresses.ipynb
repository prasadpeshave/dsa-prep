# %% [markdown]
# # 93. Restore IP Addresses
#
# Problem Link: https://leetcode.com/problems/restore-ip-addresses/
#
# ## Problem Summary
# Given a string s containing only digits, return all possible valid IP addresses.
#
# Rules:
# - Exactly 4 parts
# - Each part must be between 0 and 255
# - No leading zeros (except '0')

# %% [markdown]
# ## Approach (Backtracking)
#
# We try placing dots to form 4 segments.
#
# At each step:
# - Take 1 to 3 digits
# - Check if valid
# - Recurse further
#
# Stop when:
# - We have exactly 4 parts and used all characters

# %%
from typing import List

class Solution:
    def restoreIpAddresses(self, s: str) -> List[str]:
        res = []

        def backtrack(start, path):
            if len(path) == 4:
                if start == len(s):
                    res.append(".".join(path))
                return

            for length in range(1, 4):
                if start + length > len(s):
                    break

                part = s[start:start+length]

                if (part.startswith('0') and len(part) > 1) or int(part) > 255:
                    continue

                backtrack(start + length, path + [part])

        backtrack(0, [])
        return res

# %% [markdown]
# ## Complexity
# - Time: O(1)
# - Space: O(1)

# %%
sol = Solution()
print(sol.restoreIpAddresses("25525511135"))
print(sol.restoreIpAddresses("0000"))
print(sol.restoreIpAddresses("101023"))
# Out:
# ['255.255.11.135', '255.255.111.35']
# ['0.0.0.0']
# ['1.0.10.23', '1.0.102.3', '10.1.0.23', '10.10.2.3', '101.0.2.3']
