# %% [markdown]
# # Rotate Image
#
# **Problem Link:**
# https://leetcode.com/problems/rotate-image/description/
#
# ## Problem Statement
# You are given an `n x n` 2D `matrix` representing an image. Rotate the image **90 degrees clockwise**.
#
# You must rotate the image **in-place** — modify the input 2D matrix directly without allocating another matrix.
#
# ## Examples
#
# ### Example 1
# Input:
# ```
# [[1,2,3],
#  [4,5,6],
#  [7,8,9]]
# ```
# Output:
# ```
# [[7,4,1],
#  [8,5,2],
#  [9,6,3]]
# ```
#
# ### Example 2
# Input:
# ```
# [[5,1,9,11],
#  [2,4,8,10],
#  [13,3,6,7],
#  [15,14,12,16]]
# ```
# Output:
# ```
# [[15,13,2,5],
#  [14,3,4,1],
#  [12,6,8,9],
#  [16,7,10,11]]
# ```
#
# ## Constraints
# - `n == matrix.length == matrix[i].length`
# - `1 <= n <= 20`
# - `-1000 <= matrix[i][j] <= 1000`

# %% [markdown]
# ## Transpose + Reverse Rows
#
# ### Key Insight
# A 90° clockwise rotation can be decomposed into two simpler in-place operations:
#
# 1. **Transpose** the matrix — swap `matrix[i][j]` with `matrix[j][i]` for all `i < j`
# 2. **Reverse each row** — reverse every row left-to-right
#
# ### Why does this work?
# After a 90° clockwise rotation, the element at `(i, j)` moves to position `(j, n-1-i)`.
# - Transpose maps `(i, j)` → `(j, i)`
# - Reversing row `j` maps `(j, i)` → `(j, n-1-i)`
#
# Combining both steps achieves `(i, j)` → `(j, n-1-i)` — exactly a 90° clockwise rotation.
#
# ### Visual Example
# ```
# Original:       After Transpose:   After Row Reverse:
# 1 2 3           1 4 7              7 4 1
# 4 5 6    →      2 5 8      →       8 5 2
# 7 8 9           3 6 9              9 6 3
# ```
#
# ### Time Complexity
# - **O(n²)** — every element is visited a constant number of times
#
# ### Space Complexity
# - **O(1)** — fully in-place, no extra matrix allocated

# %%
from typing import List

class Solution:
    def rotate(self, matrix: List[List[int]]) -> None:
        """
        Do not return anything, modify matrix in-place instead.
        """
        n = len(matrix)

        # Step 1: Transpose — swap matrix[i][j] with matrix[j][i]
        for i in range(n):
            for j in range(i + 1, n):
                matrix[i][j], matrix[j][i] = matrix[j][i], matrix[i][j]

        # Step 2: Reverse each row
        for row in matrix:
            row.reverse()

# %%
import copy

def test_rotate():
    sol = Solution()

    def check(matrix, expected):
        sol.rotate(matrix)
        assert matrix == expected, f"Expected {expected}, got {matrix}"

    # Example 1
    check(
        [[1,2,3],[4,5,6],[7,8,9]],
        [[7,4,1],[8,5,2],[9,6,3]]
    )

    # Example 2
    check(
        [[5,1,9,11],[2,4,8,10],[13,3,6,7],[15,14,12,16]],
        [[15,13,2,5],[14,3,4,1],[12,6,8,9],[16,7,10,11]]
    )

    # 1x1 matrix — no change
    check([[7]], [[7]])

    # 2x2 matrix
    check(
        [[1,2],[3,4]],
        [[3,1],[4,2]]
    )

    # 4 rotations return to original
    original = [[1,2,3],[4,5,6],[7,8,9]]
    matrix   = copy.deepcopy(original)
    for _ in range(4):
        sol.rotate(matrix)
    assert matrix == original, "Four 90° rotations should return to original"

    print("All test cases passed!")

test_rotate()
# Out:
# All test cases passed!
