# %% [markdown]
# # Container With Most Water
#
# **Problem Link:**
# https://leetcode.com/problems/container-with-most-water/description/
#
# ## Problem Statement
# You are given an integer array `height` of length `n`. There are `n` vertical lines drawn such that the two endpoints of the `i`th line are `(i, 0)` and `(i, height[i])`.
#
# Find two lines that together with the x-axis form a container such that the container contains the most water.
#
# Return the maximum amount of water a container can store.
#
# > Notice that you may not slant the container.
#
# ## Examples
#
# ### Example 1
# Input: `height = [1,8,6,2,5,4,8,3,7]`
# Output: `49`
# Explanation: The max area is formed between lines at index 1 (height 8) and index 8 (height 7): `min(8,7) × (8-1) = 7 × 7 = 49`.
#
# ### Example 2
# Input: `height = [1,1]`
# Output: `1`
#
# ## Constraints
# - `n == height.length`
# - `2 <= n <= 10⁵`
# - `0 <= height[i] <= 10⁴`

# %% [markdown]
# ## Two-Pointer Approach
#
# ### Strategy
# - Place one pointer `left` at the start and one pointer `right` at the end of the array
# - At each step, compute the area formed by the two pointers:
#   `area = min(height[left], height[right]) × (right - left)`
# - Update `max_area` if this area is larger
# - Move the pointer pointing to the **shorter** line inward — keeping the taller line gives us the only chance of finding a larger area with a narrower width
# - Repeat until `left` and `right` meet
#
# ### Why move the shorter pointer?
# - The area is always bottlenecked by `min(height[left], height[right])`
# - If we move the taller pointer inward, the width decreases **and** the height can only stay the same or decrease — the area can only shrink
# - Moving the shorter pointer inward at least gives a chance of finding a taller line that compensates for the reduced width
#
# ### Time Complexity
# - **O(n)** — each pointer moves at most `n` steps in total
#
# ### Space Complexity
# - **O(1)** extra space

# %%
from typing import List

class Solution:
    def maxArea(self, height: List[int]) -> int:
        left, right = 0, len(height) - 1
        max_area = 0

        while left < right:
            area = min(height[left], height[right]) * (right - left)
            max_area = max(max_area, area)

            if height[left] < height[right]:
                left += 1
            else:
                right -= 1

        return max_area

# %%
def test_max_area():
    sol = Solution()

    assert sol.maxArea([1, 8, 6, 2, 5, 4, 8, 3, 7]) == 49
    assert sol.maxArea([1, 1])                       == 1

    # Strictly increasing — best pair is always the outermost two
    assert sol.maxArea([1, 2, 3, 4, 5])              == 6   # min(1,5) * 4

    # Strictly decreasing — same reasoning
    assert sol.maxArea([5, 4, 3, 2, 1])              == 6   # min(5,1) * 4

    # All same height
    assert sol.maxArea([4, 4, 4, 4])                 == 12  # min(4,4) * 3

    # One very tall line in the middle
    assert sol.maxArea([1, 100, 1])                  == 2   # min(1,1) * 2

    # Two elements, different heights
    assert sol.maxArea([3, 9])                       == 3   # min(3,9) * 1

    print("All test cases passed!")

test_max_area()
# Out:
# All test cases passed!
